# %% [markdown]
# # Detectando objetos com YOLO v4

# %% [markdown]
# ## Etapa 1 - Download do Darknet

# %%
# !git clone https://github.com/pjreddie/darknet.git
# Out:
# fatal: destination path 'darknet' already exists and is not an empty directory.

# %% [markdown]
# ## Etapa 2 - Compilando a biblioteca

# %%
# !cd darknet && make
# Out:
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/gemm.c -o obj/gemm.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/utils.c -o obj/utils.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/cuda.c -o obj/cuda.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/deconvolutional_layer.c -o obj/deconvolutional_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/convolutional_layer.c -o obj/convolutional_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/list.c -o obj/list.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/image.c -o obj/image.o
# ...

# %% [markdown]
# ## Etapa 3 - Baixando os pesos do modelo pré-treinado

# %%
import os
from urllib.request import urlretrieve
from urllib.parse import urlparse

weights_url = "https://data.pjreddie.com/files/yolov3.weights"
weights_basename = os.path.basename(urlparse(weights_url).path)

if not os.path.exists(weights_basename):
    print("Weights file not found. Downloading it...")
    urlretrieve(weights_url, weights_basename)
    print("Done.")
else:
    print("Weights file already exists.")
# Out:
# Weights file already exists.

# %% [markdown]
# ## Etapa 4 - Testando o detector

# %%
# Workaround to solve "Couldn't open file: (...)" and "First section must be [net] or [network]"
# !find darknet | grep -E "(.*)(\.*)$" | xargs dos2unix
# Out:
# dos2unix: Skipping darknet, not a regular file.
# dos2unix: Skipping darknet/cfg, not a regular file.
# dos2unix: converting file darknet/cfg/vgg-conv.cfg to Unix format...
# dos2unix: converting file darknet/cfg/strided.cfg to Unix format...
# dos2unix: converting file darknet/cfg/resnet50.cfg to Unix format...
# dos2unix: converting file darknet/cfg/yolov1-tiny.cfg to Unix format...
# dos2unix: converting file darknet/cfg/resnext152-32x4d.cfg to Unix format...
# dos2unix: converting file darknet/cfg/yolov2.cfg to Unix format...
# dos2unix: converting file darknet/cfg/resnet152.cfg to Unix format...
# dos2unix: converting file darknet/cfg/yolov3-openimages.cfg to Unix format...
# dos2unix: converting file darknet/cfg/rnn.train.cfg to Unix format...
# dos2unix: converting file darknet/cfg/jnet-conv.cfg to Unix format...
# dos2unix: converting file darknet/cfg/imagenet22k.dataset to Unix format...
# dos2unix: converting file darknet/cfg/darknet19.cfg to Unix format...
# ...

# %%
# !cd darknet && ./darknet detect cfg/yolov3.cfg yolov3.weights data/person.jpg
# Out:
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   608 x 608 x   3   ->   608 x 608 x  32  0.639 BFLOPs
#     1 conv     64  3 x 3 / 2   608 x 608 x  32   ->   304 x 304 x  64  3.407 BFLOPs
#     2 conv     32  1 x 1 / 1   304 x 304 x  64   ->   304 x 304 x  32  0.379 BFLOPs
#     3 conv     64  3 x 3 / 1   304 x 304 x  32   ->   304 x 304 x  64  3.407 BFLOPs
#     4 res    1                 304 x 304 x  64   ->   304 x 304 x  64
#     5 conv    128  3 x 3 / 2   304 x 304 x  64   ->   152 x 152 x 128  3.407 BFLOPs
#     6 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64  0.379 BFLOPs
#     7 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128  3.407 BFLOPs
#     8 res    5                 152 x 152 x 128   ->   152 x 152 x 128
#     9 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64  0.379 BFLOPs
#    10 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128  3.407 BFLOPs
# ...
