# %% [markdown]
# # Detectando objetos com YOLO v4

# %% [markdown]
# ## Etapa 1 - Download do Darknet

# %%
# Feito no Makefile

# %% [markdown]
# ## Etapa 2 - Compilando a biblioteca

# %%
# Feito no Makefile

# %% [markdown]
# ## Etapa 3 - Baixando os pesos do modelo pré-treinado

# %%
# Feito no Makefile

# %% [markdown]
# ## Etapa 4 - Testando o detector

# %%
DARKNET_PATH="../../shared/darknet"

# !cd {DARKNET_PATH} && ./darknet detect cfg/yolov3.cfg ../yolov3.weights data/person.jpg
# Out:
# CUDA Error: no CUDA-capable device is detected
# darknet: ./src/cuda.c:36: check_error: Assertion `0' failed.

# %% [markdown]
# ## Etapa 5 - Visualizando o resultado

# %%
from utils import mostrar_imagem

# %%
mostrar_imagem(f'{DARKNET_PATH}/predictions.jpg')
# Out:
# [ WARN:0@0.308] global loadsave.cpp:275 findDecoder imread_('../../shared/darknet/predictions.jpg'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 mostrar_imagem(f'{DARKNET_PATH}/predictions.jpg')
#
# File ~/Projetos/opencv-yolo-darknet/src/notebooks/utils.py:9, in mostrar_imagem(caminho)
#       7 fig.set_size_inches(18,10)
#       8 plt.axis('off')
# ----> 9 plt.imshow(cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB))
#      10 plt.show()
#
# error: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %% [markdown]
# ### Detectando objetos com YOLO v4 - com suporte a GPU / CUDA

# %%
import tensorflow as tf

device_name = tf.test.gpu_device_name()
device_name
# Out:
# 2025-09-07 16:17:39.673094: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-09-07 16:17:40.002197: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-09-07 16:17:41.312442: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1757272662.170819   22905 gpu_device.cc:2020] Created device /device:GPU:0 with 3620 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 6GB Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# '/device:GPU:0'
