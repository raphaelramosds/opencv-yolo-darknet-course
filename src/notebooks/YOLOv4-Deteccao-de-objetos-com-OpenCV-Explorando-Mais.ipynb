# %% [markdown]
# # Detectando objetos com YOLO e OpenCV - Explorando mais opções

# %%
import os
import sys

helpers_path = os.path.abspath("..")

sys.path.append(helpers_path)

# %% [markdown]
# ## Etapa 1 - Importando as bibliotecas

# %%
import cv2
import helpers.opencv as opencv

print(cv2.__version__)

# %% [markdown]
# ## Etapa 2 - Conectando com o Google Drive

# %%
# Desnecessario

# %% [markdown]
# ## Etapa 3 - Carregando os arquivos do modelo treinado

# %%
# detectar_objetos_cv2

# %%
# detectar_objetos_cv2

# %% [markdown]
# ## Etapa 4 - Definindo mais configurações para a detecção

# %%
# detectar_objetos_cv2

# %% [markdown]
# ## Etapa 5 - Carregando a imagem onde será feita a detecção

# %%
imagem = opencv.carregar_imagem('cachorros02.jpg')
imagem.shape

# %% [markdown]
# ## Etapa 6 - Processando a imagem de entrada

# %% [markdown]
# ### Redimensionamento da imagem (opcional)

# %%
imagem = opencv.redimensionar_imagem(imagem)

opencv.mostrar_imagem(imagem)

imagem.shape

# %% [markdown]
# ### Construindo o blob da imagem e Executar inferência

# %%
# _executar_deteccao

# %% [markdown]
# ## Etapa 7 - Definindo as variáveis

# %%
#  detectar_objetos

# %% [markdown]
# ## Etapa 8 - Realizando a predição

# %%
opencv.detectar_objetos(imagem)

# %% [markdown]
# ## Fazendo a detecção em múltiplas imagens de uma vez

# %%
for img in ["cachorros.jpg", "img-canecas.jpg", "person.jpg"]:
    try:
        imagem = opencv.carregar_imagem(img, False)
        imagem_cp = imagem.copy()
        opencv.detectar_objetos(imagem_cp)
    except:
        print("Erro ao carregar a imagem -> " + img)
        continue

# %% [markdown]
# ## Contando quantas vezes algum objeto especifico apareceu em múltiplas imagens
#
# **Exercício:** Crie um metodo `contar_objeto_cv2` que receba o label de um objeto em específico e reutilize rotinas do `detectar_objetos_cv2` para contar o número de vezes que esse objeto aparece nas imagens analisadas

# %%
contagem = 0
contagem_total = 0
label_objeto = "dog"


def contar_objeto_cv2(objeto: str, imagem: cv2.typing.MatLike): ...


for img in ["cachorros.jpg", "img-canecas.jpg", "person.jpg"]:
    try:
        imagem = opencv.carregar_imagem(img, False)
        imagem_cp = imagem.copy()
        contar_objeto_cv2(label_objeto, imagem)
        print(label_objeto + " detectados na imagem " + str(img) + ": " + str(contagem))
    except:
        print("Erro ao carregar a imagem -> " + img)
        continue

print("Total de " + label_objeto + " detectados: " + str(contagem_total))

# %% [markdown]
# ## Fazendo a detecção apenas de objetos específicos do modelo
#
# **Exercício:** Crie um metodo `detectar_objeto_cv2` que receba o label de um objeto em específico e reutilize rotinas do `detectar_objetos_cv2` para realizar a detecção apenas do objeto em questão na imagem

# %%
label_objeto = "dog"

def detectar_objeto_cv2(objeto: str, imagem: cv2.typing.MatLike): ...

for img in ["cachorros.jpg", "img-canecas.jpg", "person.jpg"]:
    try:
        imagem = opencv.carregar_imagem(img, False)
        imagem_cp = imagem.copy()
        detectar_objeto_cv2(label_objeto, imagem)
    except:
        continue
